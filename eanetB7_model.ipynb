# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, auc
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import time
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import EfficientNetB7

IMG_SIZE = 224
BATCH_SIZE = 32
NUM_CLASSES = 4
EPOCHS = 20
DATASET_PATH = "/kaggle/input/datasets/nazmul0087/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone" 

datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_generator = datagen.flow_from_directory(
    DATASET_PATH,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

val_generator = datagen.flow_from_directory(
    DATASET_PATH,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

base_model = EfficientNetB7(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)



base_model.trainable = True

for layer in base_model.layers[:-4]:
    layer.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
outputs = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=outputs)


model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

start_train_time = time.time()

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS
)

plt.figure(figsize=(8,6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()
plt.grid(True)
plt.show()

training_time = time.time() - start_train_time

start_test_time = time.time()

y_pred_prob = model.predict(val_generator)
y_pred_classes = np.argmax(y_pred_prob, axis=1)
y_true = val_generator.classes

testing_time = time.time() - start_test_time
class_names = list(val_generator.class_indices.keys())
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

class_report = classification_report(y_true, y_pred_classes, target_names=list(val_generator.class_indices.keys()))
accuracy = np.sum(y_pred_classes == y_true) / len(y_true)
print(f"Training Time: {training_time:.2f} seconds")
print(f"Testing Time: {testing_time:.2f} seconds")
print("Confusion Matrix:\n", cm)
print("Classification Report:\n", class_report)
print(f"Overall Accuracy: {accuracy:.4f}")
class_accuracy = cm.diagonal() / cm.sum(axis=1)
for i, class_name in enumerate(val_generator.class_indices.keys()):
    print(f"Accuracy for class '{class_name}': {class_accuracy[i]:.4f}")
y_true_onehot = to_categorical(y_true, num_classes=NUM_CLASSES)

plt.figure(figsize=(8, 6))
for i, class_name in enumerate(val_generator.class_indices.keys()):
    fpr, tpr, _ = roc_curve(y_true_onehot[:, i], y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_name} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc="lower right")
plt.show()


accuracy = np.sum(y_pred_classes == y_true) / len(y_true)


precision = precision_score(y_true, y_pred_classes, average='macro')
recall = recall_score(y_true, y_pred_classes, average='macro')
f1 = f1_score(y_true, y_pred_classes, average='macro')

# Print results
print(f"Overall Accuracy: {accuracy*100:.2f}%")
print(f"Precision: {precision*100:.2f}%")
print(f"Recall: {recall*100:.2f}%")
print(f"F1-Score: {f1*100:.2f}%")
# Out:
# 2026-02-21 18:23:24.738902: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771698204.949953      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771698205.008912      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771698205.464269      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771698205.464308      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771698205.464313      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771698205.464319      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Found 9959 images belonging to 4 classes.
# Found 2487 images belonging to 4 classes.
# I0000 00:00:1771698236.952564      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1771698236.958519      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258076736/258076736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771698276.906945     138 service.cc:152] XLA service 0x7abad8004a40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1771698276.907010     138 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1771698276.907016     138 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1771698284.198188     138 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-02-21 18:24:57.774568: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:24:57.920218: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:24:58.201579: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:24:58.352318: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:24:58.738296: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:24:58.897803: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:24:59.445549: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:24:59.616973: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:25:00.483157: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:25:00.652686: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:25:02.025666: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:25:02.235905: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1771698323.423041     138 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 231/312 ━━━━━━━━━━━━━━━━━━━━ 23s 289ms/step - accuracy: 0.3053 - loss: 1.3672
# 2026-02-21 18:26:48.663609: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:26:48.799428: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:26:49.039135: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:26:49.179540: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:26:49.441082: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:26:49.587374: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:26:49.970144: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:26:50.140410: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:26:50.938521: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:26:51.109099: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:26:51.278309: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:26:52.146242: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:26:52.354952: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.3227 - loss: 1.3565
# 2026-02-21 18:28:32.162373: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:28:32.300601: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:28:32.570646: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:28:32.717989: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:28:33.055810: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:28:33.210958: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:28:33.676227: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:28:33.846769: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:28:34.627786: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:28:34.796797: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:28:35.775505: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-21 18:28:35.984070: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 277s 631ms/step - accuracy: 0.3229 - loss: 1.3564 - val_accuracy: 0.4166 - val_loss: 1.2732
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 104s 331ms/step - accuracy: 0.4470 - loss: 1.2700 - val_accuracy: 0.4600 - val_loss: 1.2665
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 104s 332ms/step - accuracy: 0.4698 - loss: 1.2453 - val_accuracy: 0.4600 - val_loss: 1.2603
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 104s 332ms/step - accuracy: 0.4749 - loss: 1.2477 - val_accuracy: 0.4584 - val_loss: 1.2555
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 104s 333ms/step - accuracy: 0.4932 - loss: 1.2210 - val_accuracy: 0.4419 - val_loss: 1.2523
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 104s 332ms/step - accuracy: 0.4991 - loss: 1.2116 - val_accuracy: 0.4596 - val_loss: 1.2488
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 104s 332ms/step - accuracy: 0.5073 - loss: 1.1911 - val_accuracy: 0.4568 - val_loss: 1.2469
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 104s 332ms/step - accuracy: 0.5075 - loss: 1.1982 - val_accuracy: 0.4536 - val_loss: 1.2434
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 104s 332ms/step - accuracy: 0.5226 - loss: 1.1801 - val_accuracy: 0.4483 - val_loss: 1.2410
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 104s 332ms/step - accuracy: 0.5224 - loss: 1.1779 - val_accuracy: 0.4503 - val_loss: 1.2373
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 103s 331ms/step - accuracy: 0.5226 - loss: 1.1761 - val_accuracy: 0.4528 - val_loss: 1.2347
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 104s 332ms/step - accuracy: 0.5346 - loss: 1.1500 - val_accuracy: 0.4544 - val_loss: 1.2321
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 104s 332ms/step - accuracy: 0.5369 - loss: 1.1500 - val_accuracy: 0.4584 - val_loss: 1.2297
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 103s 331ms/step - accuracy: 0.5335 - loss: 1.1479 - val_accuracy: 0.4612 - val_loss: 1.2271
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 103s 331ms/step - accuracy: 0.5297 - loss: 1.1572 - val_accuracy: 0.4640 - val_loss: 1.2252
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 104s 333ms/step - accuracy: 0.5415 - loss: 1.1370 - val_accuracy: 0.4680 - val_loss: 1.2230
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 104s 333ms/step - accuracy: 0.5399 - loss: 1.1406 - val_accuracy: 0.4692 - val_loss: 1.2198
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 104s 332ms/step - accuracy: 0.5395 - loss: 1.1268 - val_accuracy: 0.4865 - val_loss: 1.2185
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 104s 332ms/step - accuracy: 0.5405 - loss: 1.1307 - val_accuracy: 0.4749 - val_loss: 1.2139
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 104s 333ms/step - accuracy: 0.5480 - loss: 1.1138 - val_accuracy: 0.4873 - val_loss: 1.2125
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 53s 477ms/step
# Training Time: 2248.48 seconds
# Testing Time: 53.12 seconds
# Confusion Matrix:
#  [[260 481   0   0]
#  [ 91 924   0   0]
#  [ 78 197   0   0]
#  [219 209   0  28]]
# Classification Report:
#                precision    recall  f1-score   support
#
#         Cyst       0.40      0.35      0.37       741
#       Normal       0.51      0.91      0.65      1015
#        Stone       0.00      0.00      0.00       275
#        Tumor       1.00      0.06      0.12       456
#
#     accuracy                           0.49      2487
#    macro avg       0.48      0.33      0.29      2487
# weighted avg       0.51      0.49      0.40      2487
#
# Overall Accuracy: 0.4873
# Accuracy for class 'Cyst': 0.3509
# Accuracy for class 'Normal': 0.9103
# Accuracy for class 'Stone': 0.0000
# Accuracy for class 'Tumor': 0.0614
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Overall Accuracy: 48.73%
# Precision: 47.79%
# Recall: 33.07%
# F1-Score: 28.60%
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
